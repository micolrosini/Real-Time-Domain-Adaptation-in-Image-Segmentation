# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/BiseNetv1-master
# !pip install torchvision
# !pip install tensorboardX
# !pip install thop
# !pip install wandb
# Out:
# /content/drive/MyDrive/BiseNetv1-master
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 13.6 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 73.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 17.1 MB/s eta 0:00:00
# ...

# %%
# !python flopsAndParameters.py --model "FCD"
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_relu() for <class 'torch.nn.modules.activation.LeakyReLU'>.
# [INFO] Register count_upsample() for <class 'torch.nn.modules.upsampling.Upsample'>.
# model: FCDiscriminator
# flops : 30890000384.0
# parms : 2.781M

# %%
# !python flopsAndParameters.py --model "DSC"
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_relu() for <class 'torch.nn.modules.activation.LeakyReLU'>.
# [INFO] Register count_upsample() for <class 'torch.nn.modules.upsampling.Upsample'>.
# model: DSCDiscriminator
# flops : 2146959360.0
# parms : 189.424K

# %%
# %rm -rf wandb/

# %%
# !python trainSupervised.py #SGD optimizer
# Out:
# epoch 0, lr 0.025000: 100% 500/500 [01:07<00:00,  7.46it/s, loss=2.008131]
# loss for train : 2.505086
# epoch 1, lr 0.024775: 100% 500/500 [01:05<00:00,  7.66it/s, loss=0.968284]
# loss for train : 1.330111
# epoch 2, lr 0.024550: 100% 500/500 [01:05<00:00,  7.65it/s, loss=1.072763]
# loss for train : 1.107382
# epoch 3, lr 0.024324: 100% 500/500 [01:05<00:00,  7.68it/s, loss=0.702427]
# loss for train : 0.938077
# epoch 4, lr 0.024098: 100% 500/500 [01:05<00:00,  7.60it/s, loss=1.150300]
# loss for train : 0.788914
# epoch 5, lr 0.023872: 100% 500/500 [01:05<00:00,  7.69it/s, loss=0.511030]
# loss for train : 0.704322
# start val!
# precision per pixel for test: 0.768
# mIoU for validation: 0.417
# mIoU per class: [0.94001255 0.56108529 0.80661045 0.15259094 0.12372811 0.29715773
#  0.26306264 0.41519729 0.8209703  0.41102068 0.77422431 0.49806564
#  0.14699017 0.84410527 0.03293191 0.20309904 0.10262931 0.03057843
#  0.5030175 ]
# ...

# %%
# !python trainSupervised.py #ADAM
# Out:
# epoch 0, lr 0.025000: 100% 500/500 [01:11<00:00,  6.97it/s, loss=2.915385]
# loss for train : 3.900631
# epoch 1, lr 0.024775: 100% 500/500 [01:08<00:00,  7.29it/s, loss=2.582618]
# loss for train : 2.898468
# epoch 2, lr 0.024550: 100% 500/500 [01:08<00:00,  7.29it/s, loss=1.707733]
# loss for train : 2.580368
# epoch 3, lr 0.024324: 100% 500/500 [01:08<00:00,  7.32it/s, loss=3.006453]
# loss for train : 2.394678
# epoch 4, lr 0.024098: 100% 500/500 [01:08<00:00,  7.31it/s, loss=3.517923]
# loss for train : 2.289604
# epoch 5, lr 0.023872: 100% 500/500 [01:08<00:00,  7.31it/s, loss=2.272386]
# loss for train : 2.157452
# start val!
# precision per pixel for test: 0.673
# mIoU for validation: 0.196
# mIoU per class: [0.85555444 0.15190239 0.65215627 0.         0.         0.
#  0.         0.02849962 0.72462994 0.27172905 0.68148573 0.00435072
#  0.         0.35574643 0.         0.         0.         0.
#  0.        ]
# ...

# %%
# !python trainSupervised.py #RMSPROP
# Out:
# epoch 0, lr 0.025000: 100% 500/500 [01:09<00:00,  7.22it/s, loss=3.717606]
# loss for train : 9.183900
# epoch 1, lr 0.024775: 100% 500/500 [01:06<00:00,  7.55it/s, loss=2.827247]
# loss for train : 3.253195
# epoch 2, lr 0.024550: 100% 500/500 [01:06<00:00,  7.55it/s, loss=2.031025]
# loss for train : 2.875549
# epoch 3, lr 0.024324: 100% 500/500 [01:06<00:00,  7.52it/s, loss=2.871165]
# loss for train : 2.694193
# epoch 4, lr 0.024098: 100% 500/500 [01:06<00:00,  7.52it/s, loss=2.583671]
# loss for train : 2.891368
# epoch 5, lr 0.023872: 100% 500/500 [01:06<00:00,  7.56it/s, loss=2.349602]
# loss for train : 2.507151
# start val!
# precision per pixel for test: 0.504
# mIoU for validation: 0.130
# mIoU per class: [7.16606965e-01 9.17300103e-02 3.87945743e-01 0.00000000e+00
#  0.00000000e+00 6.45683103e-04 0.00000000e+00 5.00127291e-02
#  5.31938938e-01 2.50388330e-01 1.99620722e-01 6.36179511e-02
#  0.00000000e+00 1.83445961e-01 0.00000000e+00 0.00000000e+00
# ...

# %%
# !python trainUnsupervised.py  #D = 1 OPTIMIZER D = SGD
# Out:
# 0
# 0
# 1
# epoch 0, lr 0.025000: 100% 500/500 [04:25<00:00,  1.89it/s, loss_D=0.693147, loss_segmentation_source=6.313781, loss_target=0.000693]
# loss for train source : 7.667481
# loss for train target : 0.000693
# loss for discriminator : 0.693147
# epoch 1, lr 0.024775: 100% 500/500 [03:06<00:00,  2.68it/s, loss_D=0.693147, loss_segmentation_source=5.601393, loss_target=0.000693]
# loss for train source : 5.901110
# loss for train target : 0.000693
# loss for discriminator : 0.693146
# epoch 2, lr 0.024550: 100% 500/500 [03:06<00:00,  2.68it/s, loss_D=0.693145, loss_segmentation_source=4.885490, loss_target=0.000693]
# loss for train source : 5.118621
# loss for train target : 0.000693
# loss for discriminator : 0.693146
# epoch 3, lr 0.024324: 100% 500/500 [03:06<00:00,  2.68it/s, loss_D=0.693147, loss_segmentation_source=4.467728, loss_target=0.000693]
# loss for train source : 4.677480
# loss for train target : 0.000693
# loss for discriminator : 0.693146
# ...

# %%
# !python trainUnsupervised.py  #D=0 OPTIMIZER D= ADAM
# Out:
# entrato Discriminator 0
# Type of DIscriminator (0 = FCD 1 = DSC):  0
# use pseudo labels:  0
# use pretreined model:  0
# lr:  0.00025
# epoch 0, lr 0.000250: 100% 500/500 [03:13<00:00,  2.58it/s, loss_D=0.676072, loss_segmentation_source=5.218025, loss_target=0.001721]
# loss for train source : 6.702441
# loss for train target : 0.001014
# loss for discriminator : 0.612332
# epoch 1, lr 0.000248: 100% 500/500 [03:08<00:00,  2.65it/s, loss_D=0.547850, loss_segmentation_source=4.157613, loss_target=0.001141]
# loss for train source : 4.729391
# loss for train target : 0.001354
# loss for discriminator : 0.539456
# epoch 2, lr 0.000245: 100% 500/500 [03:08<00:00,  2.65it/s, loss_D=0.479558, loss_segmentation_source=3.174945, loss_target=0.001601]
# loss for train source : 3.952157
# loss for train target : 0.001577
# loss for discriminator : 0.507645
# epoch 3, lr 0.000243: 100% 500/500 [03:08<00:00,  2.65it/s, loss_D=0.787566, loss_segmentation_source=4.576213, loss_target=0.001174]
# ...

# %%
# !python trainUnsupervised.py  #D = 1 OPTIMIZER D = ADAM
# Out:
# 0
# 0
# 1
# epoch 0, lr 0.025000: 100% 500/500 [03:06<00:00,  2.68it/s, loss_D=0.687677, loss_segmentation_source=2.021987, loss_target=0.000672]
# loss for train source : 3.012264
# loss for train target : 0.000687
# loss for discriminator : 0.692266
# epoch 1, lr 0.024775: 100% 500/500 [03:05<00:00,  2.70it/s, loss_D=0.675381, loss_segmentation_source=1.720106, loss_target=0.000728]
# loss for train source : 1.900425
# loss for train target : 0.000693
# loss for discriminator : 0.679758
# epoch 2, lr 0.024550: 100% 500/500 [03:06<00:00,  2.68it/s, loss_D=0.653260, loss_segmentation_source=1.735564, loss_target=0.000766]
# loss for train source : 1.620990
# loss for train target : 0.000745
# loss for discriminator : 0.669083
# epoch 3, lr 0.024324: 100% 500/500 [03:06<00:00,  2.68it/s, loss_D=0.599138, loss_segmentation_source=1.300452, loss_target=0.000867]
# loss for train source : 1.340252
# loss for train target : 0.000797
# loss for discriminator : 0.646850
# ...

# %%
# !python trainUnsupervised.py  #D = 1 OPTIMIZER D = RMSprop
# Out:
# 0
# 0
# 1
# epoch 0, lr 0.025000: 100% 500/500 [03:07<00:00,  2.67it/s, loss_D=0.685563, loss_segmentation_source=1.435218, loss_target=0.000711]
# loss for train source : 3.034201
# loss for train target : 0.000685
# loss for discriminator : 0.685760
# epoch 1, lr 0.024775: 100% 500/500 [02:54<00:00,  2.86it/s, loss_D=0.650247, loss_segmentation_source=1.543014, loss_target=0.000754]
# loss for train source : 1.928461
# loss for train target : 0.000743
# loss for discriminator : 0.668264
# epoch 2, lr 0.024550: 100% 500/500 [02:55<00:00,  2.84it/s, loss_D=0.647750, loss_segmentation_source=1.132550, loss_target=0.000828]
# loss for train source : 1.610852
# loss for train target : 0.000767
# loss for discriminator : 0.661414
# epoch 3, lr 0.024324: 100% 500/500 [02:56<00:00,  2.84it/s, loss_D=0.632470, loss_segmentation_source=1.078034, loss_target=0.000894]
# loss for train source : 1.326972
# loss for train target : 0.000815
# loss for discriminator : 0.642273
# ...

# %%
# !python createpseudolabels.py #crea le pseudo label
# Out:
# Upload Model...
# ./checkpoints_101_sgd/model_output_best.pth
# Creating pseudo labels....
# pseudo label created
# PSEUDOLABEL CREATE

# %%
# !python trainUnsupervised.py #with pseudo labels #lr 2.5e-2
# Out:
# entrato nel dataset_train_target delle pseudo
# Type of DIscriminator (0 = FCD 1 = DSC):  1
# use pseudo labels:  1
# use pretreined model:  0
# epoch 0, lr 0.025000: 100% 500/500 [03:14<00:00,  2.57it/s, loss_D=0.683746, loss_segmentation_source=1.447878, loss_target=1.248652]
# loss for train source : 2.700054
# loss for train target : 2.000506
# loss for discriminator : 0.690939
# epoch 1, lr 0.024775: 100% 500/500 [03:10<00:00,  2.62it/s, loss_D=0.655880, loss_segmentation_source=1.662377, loss_target=0.799414]
# loss for train source : 1.670448
# loss for train target : 1.126076
# loss for discriminator : 0.666813
# epoch 2, lr 0.024550: 100% 500/500 [03:11<00:00,  2.62it/s, loss_D=0.689622, loss_segmentation_source=1.423531, loss_target=0.950849]
# loss for train source : 1.334644
# loss for train target : 0.898307
# loss for discriminator : 0.654139
# ...

# %%
# !python trainUnsupervised.py #with pseudo labels #lr 1.25e-2
# Out:
# entrato nel dataset_train_target delle pseudo
# Type of DIscriminator (0 = FCD 1 = DSC):  1
# use pseudo labels:  1
# use pretreined model:  0
# lr:  0.0125
# epoch 0, lr 0.012500: 100% 500/500 [03:28<00:00,  2.40it/s, loss_D=0.672529, loss_segmentation_source=1.413945, loss_target=1.114399]
# loss for train source : 2.583331
# loss for train target : 1.998374
# loss for discriminator : 0.690531
# epoch 1, lr 0.012387: 100% 500/500 [03:15<00:00,  2.55it/s, loss_D=0.647262, loss_segmentation_source=1.009323, loss_target=0.771541]
# loss for train source : 1.447254
# loss for train target : 0.964166
# loss for discriminator : 0.662121
# epoch 2, lr 0.012275: 100% 500/500 [03:15<00:00,  2.55it/s, loss_D=0.642575, loss_segmentation_source=1.478586, loss_target=0.593056]
# loss for train source : 1.170142
# loss for train target : 0.794680
# loss for discriminator : 0.651134
# ...

# %%
# !python trainUnsupervised.py #with pseudo labels #lr 5.00e-2
# Out:
# entrato nel dataset_train_target delle pseudo
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 93.7MB/s]
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100% 171M/171M [00:04<00:00, 39.0MB/s]
# Type of DIscriminator (0 = FCD 1 = DSC):  1
# use pseudo labels:  1
# use pretreined model:  0
# lr:  0.05
# epoch 0, lr 0.050000: 100% 500/500 [04:28<00:00,  1.86it/s, loss_D=0.691662, loss_segmentation_source=2.491545, loss_target=2.129128]
# loss for train source : 3.580521
# loss for train target : 2.803274
# loss for discriminator : 0.691834
# epoch 1, lr 0.049550: 100% 500/500 [03:10<00:00,  2.63it/s, loss_D=0.663798, loss_segmentation_source=2.387151, loss_target=1.870780]
# loss for train source : 2.471248
# loss for train target : 1.772649
# loss for discriminator : 0.662646
# ...

# %%
# !python trainUnsupervised.py # learning rate = 2.5 e-4
# Out:
# entrato nel dataset_train_target delle pseudo
# Type of DIscriminator (0 = FCD 1 = DSC):  1
# use pseudo labels:  1
# use pretreined model:  0
# lr:  0.00025
# epoch 0, lr 0.000250: 100% 500/500 [03:06<00:00,  2.69it/s, loss_D=0.692134, loss_segmentation_source=5.567960, loss_target=3.965975]
# loss for train source : 6.029927
# loss for train target : 5.772784
# loss for discriminator : 0.691035
# epoch 1, lr 0.000248: 100% 500/500 [03:08<00:00,  2.65it/s, loss_D=0.683393, loss_segmentation_source=3.039819, loss_target=2.755714]
# loss for train source : 4.005607
# loss for train target : 3.543227
# loss for discriminator : 0.673438
# epoch 2, lr 0.000245: 100% 500/500 [03:09<00:00,  2.63it/s, loss_D=0.644263, loss_segmentation_source=2.690439, loss_target=3.373476]
# loss for train source : 3.214929
# loss for train target : 2.777225
# loss for discriminator : 0.665207
# ...
